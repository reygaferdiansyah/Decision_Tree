# %% [markdown]
# <a href="https://colab.research.google.com/github/reygaferdiansyah/Decision_Tree/blob/main/HousePrices_DecisionTree_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV


plt.rcParams["figure.figsize"] = (20, 10)

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
def get_missed_values_stat(df):
    missed_stat = df.isna().sum().sort_values(ascending=False).reset_index()
    missed_stat.columns = ['feature', 'NaN count']
    missed_stat['NaN share'] = missed_stat['NaN count'] / df.shape[0]
    return missed_stat[missed_stat['NaN count'] > 0]

# %%
def get_common_missed_data(df_train, df_test):
    missed_train = get_missed_values_stat(df_train)
    missed_test = get_missed_values_stat(df_test)

    missed_data = missed_train.merge(missed_test, how='outer', on='feature', suffixes=['_train', '_test'])

    return missed_data

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#          feature  NaN count_train  NaN share_train  NaN count_test  \
# 0         PoolQC           1453.0         0.995205          1456.0
# 1    MiscFeature           1406.0         0.963014          1408.0
# 2          Alley           1369.0         0.937671          1352.0
# 3          Fence           1179.0         0.807534          1169.0
# 4    FireplaceQu            690.0         0.472603           730.0
# 5    LotFrontage            259.0         0.177397           227.0
# 6    GarageYrBlt             81.0         0.055479            78.0
# 7     GarageCond             81.0         0.055479            78.0
# 8     GarageType             81.0         0.055479            76.0
# 9   GarageFinish             81.0         0.055479            78.0
# 10    GarageQual             81.0         0.055479            78.0
# 11  BsmtFinType2             38.0         0.026027            42.0
# 12  BsmtExposure             38.0         0.026027            44.0
# 13      BsmtQual             37.0         0.025342            44.0
# 14      BsmtCond             37.0         0.025342            45.0
# 15  BsmtFinType1             37.0         0.025342            42.0
# 16    MasVnrArea              8.0         0.005479            15.0
# 17    MasVnrType              8.0         0.005479            16.0
# 18    Electrical              1.0         0.000685             NaN
# 19      MSZoning              NaN              NaN             4.0
# 20  BsmtHalfBath              NaN              NaN             2.0
# 21     Utilities              NaN              NaN             2.0
# 22    Functional              NaN              NaN             2.0
# 23  BsmtFullBath              NaN              NaN             2.0
# 24    BsmtFinSF1              NaN              NaN             1.0
# 25    BsmtFinSF2              NaN              NaN             1.0
# 26     BsmtUnfSF              NaN              NaN             1.0
# 27   KitchenQual              NaN              NaN             1.0
# 28   TotalBsmtSF              NaN              NaN             1.0
# 29   Exterior2nd              NaN              NaN             1.0
# 30    GarageCars              NaN              NaN             1.0
# 31   Exterior1st              NaN              NaN             1.0
# 32    GarageArea              NaN              NaN             1.0
# 33      SaleType              NaN              NaN             1.0
#
#     NaN share_test
# 0         0.997944
# 1         0.965045
# 2         0.926662
# 3         0.801234
# 4         0.500343
# 5         0.155586
# 6         0.053461
# 7         0.053461
# 8         0.052090
# 9         0.053461
# 10        0.053461
# 11        0.028787
# 12        0.030158
# 13        0.030158
# 14        0.030843
# 15        0.028787
# 16        0.010281
# 17        0.010966
# 18             NaN
# 19        0.002742
# 20        0.001371
# 21        0.001371
# 22        0.001371
# 23        0.001371
# 24        0.000685
# 25        0.000685
# 26        0.000685
# 27        0.000685
# 28        0.000685
# 29        0.000685
# 30        0.000685
# 31        0.000685
# 32        0.000685
# 33        0.000685

# %%
columns_to_drop = missed_data.loc[missed_data['NaN share_train'] > 0.1, 'feature'].values
columns_to_drop
# Out:
# array(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
#        'LotFrontage'], dtype=object)

# %%
df_train = df_train.drop(columns=columns_to_drop)
df_test = df_test.drop(columns=columns_to_drop)

# %%
df_train.shape, df_test.shape
# Out:
# ((1460, 75), (1459, 74))

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#          feature  NaN count_train  NaN share_train  NaN count_test  \
# 0     GarageType             81.0         0.055479            76.0
# 1     GarageCond             81.0         0.055479            78.0
# 2    GarageYrBlt             81.0         0.055479            78.0
# 3   GarageFinish             81.0         0.055479            78.0
# 4     GarageQual             81.0         0.055479            78.0
# 5   BsmtFinType2             38.0         0.026027            42.0
# 6   BsmtExposure             38.0         0.026027            44.0
# 7   BsmtFinType1             37.0         0.025342            42.0
# 8       BsmtCond             37.0         0.025342            45.0
# 9       BsmtQual             37.0         0.025342            44.0
# 10    MasVnrArea              8.0         0.005479            15.0
# 11    MasVnrType              8.0         0.005479            16.0
# 12    Electrical              1.0         0.000685             NaN
# 13      MSZoning              NaN              NaN             4.0
# 14  BsmtFullBath              NaN              NaN             2.0
# 15     Utilities              NaN              NaN             2.0
# 16    Functional              NaN              NaN             2.0
# 17  BsmtHalfBath              NaN              NaN             2.0
# 18    BsmtFinSF1              NaN              NaN             1.0
# 19    BsmtFinSF2              NaN              NaN             1.0
# 20     BsmtUnfSF              NaN              NaN             1.0
# 21   TotalBsmtSF              NaN              NaN             1.0
# 22   KitchenQual              NaN              NaN             1.0
# 23   Exterior2nd              NaN              NaN             1.0
# 24   Exterior1st              NaN              NaN             1.0
# 25    GarageArea              NaN              NaN             1.0
# 26      SaleType              NaN              NaN             1.0
# 27    GarageCars              NaN              NaN             1.0
#
#     NaN share_test
# 0         0.052090
# 1         0.053461
# 2         0.053461
# 3         0.053461
# 4         0.053461
# 5         0.028787
# 6         0.030158
# 7         0.028787
# 8         0.030843
# 9         0.030158
# 10        0.010281
# 11        0.010966
# 12             NaN
# 13        0.002742
# 14        0.001371
# 15        0.001371
# 16        0.001371
# 17        0.001371
# 18        0.000685
# 19        0.000685
# 20        0.000685
# 21        0.000685
# 22        0.000685
# 23        0.000685
# 24        0.000685
# 25        0.000685
# 26        0.000685
# 27        0.000685

# %%
garage_cat_features = ['GarageType', 'GarageCond', 'GarageFinish', 'GarageQual']

# %%
for feature in garage_cat_features:
    df_train[feature] = df_train[feature].fillna('None')
    df_test[feature] = df_test[feature].fillna('None')

# %%
garage_num_features = ['GarageYrBlt', 'GarageCars', 'GarageArea']

# %%
for feature in garage_num_features:
    df_train[feature] = df_train[feature].fillna(0)
    df_test[feature] = df_test[feature].fillna(0)

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#          feature  NaN count_train  NaN share_train  NaN count_test  \
# 0   BsmtFinType2             38.0         0.026027            42.0
# 1   BsmtExposure             38.0         0.026027            44.0
# 2   BsmtFinType1             37.0         0.025342            42.0
# 3       BsmtQual             37.0         0.025342            44.0
# 4       BsmtCond             37.0         0.025342            45.0
# 5     MasVnrType              8.0         0.005479            16.0
# 6     MasVnrArea              8.0         0.005479            15.0
# 7     Electrical              1.0         0.000685             NaN
# 8       MSZoning              NaN              NaN             4.0
# 9   BsmtHalfBath              NaN              NaN             2.0
# 10    Functional              NaN              NaN             2.0
# 11  BsmtFullBath              NaN              NaN             2.0
# 12     Utilities              NaN              NaN             2.0
# 13   Exterior1st              NaN              NaN             1.0
# 14    BsmtFinSF2              NaN              NaN             1.0
# 15     BsmtUnfSF              NaN              NaN             1.0
# 16   TotalBsmtSF              NaN              NaN             1.0
# 17   KitchenQual              NaN              NaN             1.0
# 18    BsmtFinSF1              NaN              NaN             1.0
# 19   Exterior2nd              NaN              NaN             1.0
# 20      SaleType              NaN              NaN             1.0
#
#     NaN share_test
# 0         0.028787
# 1         0.030158
# 2         0.028787
# 3         0.030158
# 4         0.030843
# 5         0.010966
# 6         0.010281
# 7              NaN
# 8         0.002742
# 9         0.001371
# 10        0.001371
# 11        0.001371
# 12        0.001371
# 13        0.000685
# 14        0.000685
# 15        0.000685
# 16        0.000685
# 17        0.000685
# 18        0.000685
# 19        0.000685
# 20        0.000685

# %%
bsmt_cat_features = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']

# %%
for feature in bsmt_cat_features:
    df_train[feature] = df_train[feature].fillna('None')
    df_test[feature] = df_test[feature].fillna('None')

# %%
bsmt_num_features = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath']

# %%
for feature in bsmt_num_features:
    df_train[feature] = df_train[feature].fillna(0)
    df_test[feature] = df_test[feature].fillna(0)

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#        feature  NaN count_train  NaN share_train  NaN count_test  \
# 0   MasVnrType              8.0         0.005479            16.0
# 1   MasVnrArea              8.0         0.005479            15.0
# 2   Electrical              1.0         0.000685             NaN
# 3     MSZoning              NaN              NaN             4.0
# 4    Utilities              NaN              NaN             2.0
# 5   Functional              NaN              NaN             2.0
# 6  Exterior1st              NaN              NaN             1.0
# 7     SaleType              NaN              NaN             1.0
# 8  Exterior2nd              NaN              NaN             1.0
# 9  KitchenQual              NaN              NaN             1.0
#
#    NaN share_test
# 0        0.010966
# 1        0.010281
# 2             NaN
# 3        0.002742
# 4        0.001371
# 5        0.001371
# 6        0.000685
# 7        0.000685
# 8        0.000685
# 9        0.000685

# %%
df_train[missed_data['feature']]
# Out:
#      MasVnrType  MasVnrArea Electrical MSZoning Utilities Functional  \
# 0       BrkFace       196.0      SBrkr       RL    AllPub        Typ
# 1          None         0.0      SBrkr       RL    AllPub        Typ
# 2       BrkFace       162.0      SBrkr       RL    AllPub        Typ
# 3          None         0.0      SBrkr       RL    AllPub        Typ
# 4       BrkFace       350.0      SBrkr       RL    AllPub        Typ
# ...         ...         ...        ...      ...       ...        ...
# 1455       None         0.0      SBrkr       RL    AllPub        Typ
# 1456      Stone       119.0      SBrkr       RL    AllPub       Min1
# 1457       None         0.0      SBrkr       RL    AllPub        Typ
# 1458       None         0.0      FuseA       RL    AllPub        Typ
# 1459       None         0.0      SBrkr       RL    AllPub        Typ
#
#      Exterior1st SaleType Exterior2nd KitchenQual
# 0        VinylSd       WD     VinylSd          Gd
# 1        MetalSd       WD     MetalSd          TA
# 2        VinylSd       WD     VinylSd          Gd
# 3        Wd Sdng       WD     Wd Shng          Gd
# 4        VinylSd       WD     VinylSd          Gd
# ...          ...      ...         ...         ...
# 1455     VinylSd       WD     VinylSd          TA
# 1456     Plywood       WD     Plywood          TA
# 1457     CemntBd       WD     CmentBd          Gd
# 1458     MetalSd       WD     MetalSd          Gd
# 1459     HdBoard       WD     HdBoard          TA
#
# [1460 rows x 10 columns]

# %%
df_train['MasVnrArea'] = df_train['MasVnrArea'].fillna(0)
df_test['MasVnrArea'] = df_test['MasVnrArea'].fillna(0)

# %%
df_train['Electrical'].mode()[0]
# Out:
# 'SBrkr'

# %%
df_train['Electrical'] = df_train['Electrical'].fillna(df_train['Electrical'].mode()[0])

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#        feature  NaN count_train  NaN share_train  NaN count_test  \
# 0   MasVnrType              8.0         0.005479              16
# 1     MSZoning              NaN              NaN               4
# 2    Utilities              NaN              NaN               2
# 3   Functional              NaN              NaN               2
# 4  Exterior2nd              NaN              NaN               1
# 5     SaleType              NaN              NaN               1
# 6  Exterior1st              NaN              NaN               1
# 7  KitchenQual              NaN              NaN               1
#
#    NaN share_test
# 0        0.010966
# 1        0.002742
# 2        0.001371
# 3        0.001371
# 4        0.000685
# 5        0.000685
# 6        0.000685
# 7        0.000685

# %%
for feature in missed_data['feature']:
    print(feature, df_test[feature].mode()[0])
    df_test[feature] = df_test[feature].fillna(df_test[feature].mode()[0])
# Out:
# MasVnrType None
# MSZoning RL
# Utilities AllPub
# Functional Typ
# Exterior2nd VinylSd
# SaleType WD
# Exterior1st VinylSd
# KitchenQual TA

# %%
missed_data = get_common_missed_data(df_train, df_test)
missed_data
# Out:
#       feature  NaN count_train  NaN share_train  NaN count_test  \
# 0  MasVnrType                8         0.005479             NaN
#
#    NaN share_test
# 0             NaN

# %%
num_to_cat_features = ['MSSubClass', 'OverallQual', 'OverallCond']

# %%
for feature in num_to_cat_features:
    df_train[feature] = df_train[feature].astype(str)
    df_test[feature] = df_test[feature].astype(str)

# %%
TARGET = 'SalePrice'
COLUMNS_TO_DROP = ['Id', 'SalePrice']

def preprocess_data(data, columns_to_drop, target):
    X = data.drop(columns=columns_to_drop)
    y = data[target]
    return X, y

X_train, y_train = preprocess_data(df_train, COLUMNS_TO_DROP, TARGET)
ohe = OneHotEncoder(handle_unknown='ignore')
X_train = ohe.fit_transform(X_train)

# %%
def log_rmse(y_true, y_pred, **kwargs):
    return mean_squared_error(np.log(y_true), np.log(y_pred), squared=False)

# %%
log_rmse_scorer = make_scorer(log_rmse, greater_is_better=False)

# %%
best_score = None
best_depth = None

for max_depth in np.arange(1, 20):
    reg = DecisionTreeRegressor(max_depth=max_depth, random_state=42)

    scores = -cross_val_score(reg, X_train, y_train, scoring=log_rmse_scorer)

    current_score = np.mean(scores)

    if best_score is None or current_score < best_score:
        best_score = current_score
        best_depth = max_depth


print(best_depth, best_score)
# Out:
# 9 0.23539015068165803

# %%
param_grid = [{'criterion': ['squared_error', 'friedman_mse'], 'max_depth': range(1, 20, 1)},
              {'criterion': ['squared_error', 'friedman_mse'], 'min_samples_leaf': range(1, 5, 1)}]

# %%
reg = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid=param_grid, scoring=log_rmse_scorer)

# %%
reg.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=42),
#              param_grid=[{'criterion': ['squared_error', 'friedman_mse'],
#                           'max_depth': range(1, 20)},
#                          {'criterion': ['squared_error', 'friedman_mse'],
#                           'min_samples_leaf': range(1, 5)}],
#              scoring=make_scorer(log_rmse, greater_is_better=False))

# %%
print(reg.best_params_)
print(reg.best_score_)
# Out:
# {'criterion': 'squared_error', 'min_samples_leaf': 4}
# -0.22790944082063377

# %%
lin_reg_param_grid = {'alpha': [0.001, 0.01, 0.1]}

# %%
lin_reg = GridSearchCV(Ridge(), param_grid=lin_reg_param_grid, scoring=log_rmse_scorer)

# %%
lin_reg.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(), param_grid={'alpha': [0.001, 0.01, 0.1]},
#              scoring=make_scorer(log_rmse, greater_is_better=False))

# %%
print(lin_reg.best_params_)
print(lin_reg.best_score_)
# Out:
# {'alpha': 0.1}
# -0.17070034506948337

# %%
X_test = df_test.drop(columns=COLUMNS_TO_DROP, errors='ignore')
X_test = ohe.transform(X_test)

# %%
y_test_pred = lin_reg.predict(X_test)

# %%
y_test_pred
# Out:
# array([121045.25485794, 148479.71350149, 195021.12914627, ...,
#        167818.59686053, 104643.10526456, 245455.33130642])

# %%
output = pd.DataFrame({'Id': df_test['Id'], 'SalePrice': y_test_pred})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
